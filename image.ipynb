# %% [markdown]
# ## Dog and Cat Classification
# # CNN - convolutional Neural Network
# CNN = directly connected to computer vision
# RNN = natural language processing
#
# DL =>  CNN - RNN - ANN

# %%
! pip install opencv-python

# %%
! pip install pillow

# %%
import numpy as np
import pandas as pd
import cv2       # open cv
import os
from PIL  import Image
print("libraries imported")
# Out:
# libraries imported

# %%
cat_image_demp_file_path = (r"Data\images\cats\cat_78.jpg")

# %%
cat = Image.open(cat_image_demp_file_path)

# %%
cat
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
cat_image = np.array(cat)
cat_image.shape
# Out:
# (225, 225, 3)

# %%
# read numpy array from

# %%
ls
# Out:
#  Volume in drive D is Local Disk
#  Volume Serial Number is 5CA5-E04B
#
#  Directory of d:\Internship\Internship Upflair\python111\Deep Learning\CNN
#
# 30-07-2024  17:18    <DIR>          .
# 30-07-2024  16:50    <DIR>          ..
# 30-07-2024  16:49    <DIR>          Data
# 30-07-2024  16:50                 0 image.ipynb
#                1 File(s)              0 bytes
#                3 Dir(s)  213,787,967,488 bytes free

# %%
pwd
# Out:
# 'd:\\Internship\\Internship Upflair\\python111\\Deep Learning\\CNN'

# %%
path_dict = {'cats':[],'dogs':[]}
image_folder_path = ("Data\images")
for dire in os.listdir(image_folder_path):
    directory_path = os.path.join(image_folder_path,dire)
    for image_name in os.listdir(directory_path):
        path_dict[dire].append(os.path.join(directory_path,image_name))
        #print(image)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\i'
# <>:2: SyntaxWarning: invalid escape sequence '\i'
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_12056\1812953478.py:2: SyntaxWarning: invalid escape sequence '\i'
#   image_folder_path = ("Data\images")

# %%
path_dict['cats'][2]
# Out:
# 'Data\\images\\cats\\cat_100.jpg'

# %%
Image.open(path_dict['dogs'][235])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=933x622>

# %%
Image.open(path_dict['dogs'][213])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1200>

# %%
# path_dict['cats'][213]
# np.array(Image.open(path_dict['cats'][213]))

# %%
cv2.imread(path_dict['cats'][2])


x = []   # <=========== images
y  = []    # <==========cats
